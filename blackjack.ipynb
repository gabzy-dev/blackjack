# %%
import random

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %%
class Card: 
    def __init__(self,suit,rank): 
        self.suit = suit 
        self.rank = rank 

    def __str__(self): 
        return self.rank+ " of "+self.suit 

###Deck__cclass
class Deck: 
    def __init__(self): 
        self.deck = [] ##start the deck with an empty list 
        for suit in suits: 
            for rank in ranks: 
                self.deck.append(Card(suit,rank))
    def __str__(self): 
        deck_comp = ' '
        for card in self.deck: 
            deck_comp += '\n' + card.__str__() 
        return f"the deck has {deck_comp}"

#####shuffling_the_deck 
    
    def shuffle(self): 
        random.shuffle(self.deck) 

    def deal(self): 
        single_card = self.deck.pop() 
        return single_card

# %%
testing = Deck()
testing.shuffle()
print(testing)
# Out:
# the deck has
# Eight of Clubs
# Seven of Clubs
# Two of Hearts
# Seven of Diamonds
# Four of Hearts
# Four of Clubs
# Nine of Clubs
# Nine of Spades
# Two of Spades
# Six of Hearts
# Queen of Diamonds
# King of Spades
# Ten of Diamonds
# Eight of Diamonds
# Six of Diamonds
# Jack of Clubs
# Ten of Hearts
# Ten of Clubs
# Five of Clubs
# Four of Spades
# Jack of Spades
# Queen of Spades
# Five of Spades
# Ace of Hearts
# Five of Hearts
# Jack of Diamonds
# Ten of Spades
# Ace of Diamonds
# Three of Diamonds
# Ace of Clubs
# Eight of Hearts
# Seven of Spades
# Four of Diamonds
# King of Hearts
# Queen of Hearts
# Five of Diamonds
# Three of Hearts
# Jack of Hearts
# Ace of Spades
# Three of Clubs
# Six of Spades
# Queen of Clubs
# Eight of Spades
# Two of Diamonds
# Nine of Hearts
# King of Diamonds
# Three of Spades
# Six of Clubs
# Seven of Hearts
# Nine of Diamonds
# Two of Clubs
# King of Clubs

# %%
class Hand:
    def __init__(self): 
        self.cards = [] ##you start the list of cards with an empty list
        self.value = 0  ##set the values of your card to zero for a start
        self.aces = 0    ##set your aces to zero as well 

    def add_card(self,card): 
        self.cards.append(card)
        self.value += values[card.rank]

        if card.rank == 'Ace': 
            self.aces += 1 
            
            

    def adjust_for_ace(self): 
        while self.value > 21 and self.aces > 0: 
            self.value -= 10
            self.aces  -= 1

# %%
###creating the chips class 
class chips: 
    def __init__(self,total = 100): 
        self.total = total
        self.bet = 0 

    def win_bet(self):
        self.total += self.bet 

    def loose_bet(self): 
        self.total -= self.bet

# %%
########function/ logic that plays the game 

def take_bet(chips): 
    while True: 
        try:
            chips.bet = int(input('how many chips will you like to play today ?'))
        except: 
            print('sorry you did not imput an integer')
        else:
            if chips.bet > chips.total: 
                print(f"sorry your bet is higher than your total value, you have{chips.total}left")
            else: 
                break

# %%
###function to take hits 
def hit(deck,hand): 
    single_card = deck.deal() 
    hand.add_card(single_card) 
    hand.adjust_for_aces()

# %%
######function asking if a player will take hits or stand
def hit_or_stand(deck,hands): 
    global playing
    
    while True: 
        x = input('hit or stand ? enter h or s')
        if x[0].lower() == 'h': 
            hit(deck,hand)

        elif x[0].lower() == 's':  
            print('player decides to stand, its dealers turn.')
            playing = False 

        else: 
            print('please select either h to hit or s to stay')
            continue 
        break

# %%
#at the start of the game the dealer has one card faced up and the other down while the. 
def show_some(player,dealer): 
    ##since we are only showing one of the dealers cards 
    print("\n dealer's hand : ")
    print("first card hidden")
    print(dealer.card[1])
     
    
    
    ##show the 2 cards with the player
    print('\n print players hand')
    for card in player.cards: 
        print(card)
    
    


def show_all(player,dealer):  
    ##this prints the card with both the dealer and player
    for card in dealer.cards:##show all the cards with dealer
        print("\n dealer's hand : ")
        print(f"value of dealers hand {dealer.value}")
        print(card)

    for card in player.cards:
        print('\n print players hand')##show all the cards with player.
        print(f"value of players hand {player.value}")
        print(card)

# %%
###function to handle win or loose scenarios 
def player_busts(player,dealer,chips): 
    print('player busted')
    chips.lose_bet() 

def player_wins(player,dealer,chips): 
    print('player wins')
    chips.win_bet()


def dealer_busts(player,dealer,chips): 
    print('dealer busted! player wins')
    chips.win_bet() 


def dealer_wins(player,dealer,chips): 
    print('dealer wins! player bursted')
    chips.lose_bet() 

def push(player,dealer): 
    print('player and dealer have a TIE!')

# %%
###########logic to play the game
while True: 
    print('WELCOME! YOU MAY BEGIN BLACKJACK!')
    deck = deck() 
    deck.shuffle() 

    player_hand = Hand()  ##give cards to each players
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())

    dealer_hand = Hand()  ##give cards to the dealer as well. 
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
# Out:
# WELCOME! YOU MAY BEGIN BLACKJACK!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 4
#       2 while True:
#       3     print('WELCOME! YOU MAY BEGIN BLACKJACK!')
# ----> 4     deck = deck()
#       5     deck.shuffle()
#       7     player_hand = Hand()  ##give cards to each players
#
# NameError: name 'deck' is not defined

# %%
# !git add "blackjack"
# !git commit -m "logic fot "
# !git push -u origin main
